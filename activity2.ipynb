# %% [markdown]
# Activity to do:
# Develop a program to implement k-Nearest Neighbour algorithm to classify the randomly generated 100 values of X in the range of [0 1]. Perform the following based on dataset generated" a. Label the first 50 points {x1, ..., x50} as follows; if xi <= 0.5 then xi blongs to class C1 else class C2. b. Classify the remaining points {x51, ..., x100} using KNN. Perform this for k = 1,2,3,4,5,20,30.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier

# Step 1: Generate 100 random values between 0 and 1
np.random.seed(42)  # For reproducibility
X = np.random.rand(100).reshape(-1, 1)  # Reshape for sklearn compatibility

# Step 2: Label the first 50 points based on the rule
y = np.array(["C1" if x <= 0.5 else "C2" for x in X[:50]])  # Assign labels

# Step 3: Initialize test data (x51 to x100) with unknown labels
X_train, y_train = X[:50], y      # First 50 for training
X_test = X[50:]                   # Last 50 for testing

# Step 4: Classify using KNN for different values of k
k_values = [1, 2, 3, 4, 5, 20, 30]
results = {}

for k in k_values:
    knn = KNeighborsClassifier(n_neighbors=k)  # Initialize KNN with k
    knn.fit(X_train, y_train)                  # Train the model
    y_pred = knn.predict(X_test)               # Predict labels for X_test
    
    results[k] = y_pred  # Store predictions for this k
    print(f"\nResults for k={k}:")
    print(y_pred)

# Step 5: Visualizing classification results
plt.figure(figsize=(10, 5))
for k in k_values:
    plt.scatter(X_test, results[k], label=f'k={k}', alpha=0.6)

plt.axvline(0.5, color='red', linestyle='--', label='Decision Boundary (0.5)')
plt.xlabel("X values")
plt.ylabel("Predicted Class")
plt.legend()
plt.title("KNN Classification for Different k Values")
plt.show()
# Out:
# Results for k=1:
# ['C2' 'C2' 'C2' 'C2' 'C2' 'C2' 'C1' 'C1' 'C1' 'C1' 'C1' 'C1' 'C2' 'C1'
#  'C1' 'C2' 'C1' 'C2' 'C1' 'C2' 'C2' 'C1' 'C1' 'C2' 'C2' 'C2' 'C2' 'C1'
#  'C1' 'C1' 'C2' 'C2' 'C1' 'C1' 'C1' 'C1' 'C2' 'C2' 'C2' 'C1' 'C1' 'C2'
#  'C2' 'C2' 'C2' 'C1' 'C2' 'C1' 'C1' 'C1']
#
# Results for k=2:
# ['C2' 'C2' 'C2' 'C2' 'C2' 'C2' 'C1' 'C1' 'C1' 'C1' 'C1' 'C1' 'C2' 'C1'
#  'C1' 'C2' 'C1' 'C2' 'C1' 'C2' 'C2' 'C1' 'C1' 'C2' 'C2' 'C2' 'C2' 'C1'
#  'C1' 'C1' 'C2' 'C2' 'C1' 'C1' 'C1' 'C1' 'C2' 'C2' 'C2' 'C1' 'C1' 'C2'
#  'C2' 'C2' 'C2' 'C1' 'C2' 'C1' 'C1' 'C1']
#
# Results for k=3:
# ['C2' 'C2' 'C2' 'C2' 'C2' 'C2' 'C1' 'C1' 'C1' 'C1' 'C1' 'C1' 'C2' 'C1'
#  'C1' 'C2' 'C1' 'C2' 'C1' 'C2' 'C2' 'C1' 'C1' 'C2' 'C2' 'C2' 'C2' 'C1'
#  'C1' 'C1' 'C2' 'C2' 'C1' 'C1' 'C1' 'C1' 'C2' 'C2' 'C2' 'C1' 'C1' 'C2'
#  'C2' 'C2' 'C2' 'C2' 'C2' 'C1' 'C1' 'C1']
#
# Results for k=4:
# ['C2' 'C2' 'C2' 'C2' 'C2' 'C2' 'C1' 'C1' 'C1' 'C1' 'C1' 'C1' 'C2' 'C1'
# ...
