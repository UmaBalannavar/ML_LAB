# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %%
df = pd.read_csv('testdata.csv')
df.head()
# Out:
#    Sl. No  Temperature  Preasure
# 0       1            2     0.0002
# 1       2           20     0.0012
# 2       3           40     0.0060
# 3       4           60     0.0300
# 4       5           80     0.0900

# %%
temperature = df.iloc[:, 1:2].values #Input 
preasure = df.iloc[:, 2].values #output

# %%
polyreg = PolynomialFeatures(degree=3)
X_poly = polyreg.fit_transform(temperature) #Transforming the input data into polynomial features
linreg = LinearRegression()
linreg.fit(X_poly, preasure) #Fitting the model with the transformed data
#Predicting the output with the transformed input data
predicted_preasure = linreg.predict(X_poly)

#Visualising the results
plt.scatter(temperature, preasure, color='red')
plt.scatter(temperature, predicted_preasure, color='blue')
plt.title('Temperature vs Preasure')
plt.xlabel('Temperature')
plt.ylabel('Preasure')
plt.legend(['Real Data', 'Predicted'])
plt.grid()
plt.show()

# %% [markdown]
# *ACTIVITY*

# %%
# Change the degree of the polynomial
degree = 2  # Try different values like 2, 3, 4, etc.
polyreg = PolynomialFeatures(degree=degree)

# Transform the input data into polynomial features
X_poly = polyreg.fit_transform(temperature)

# Fit the model with the transformed data
linreg = LinearRegression()
linreg.fit(X_poly, preasure)

# Predict the output with the transformed input data
predicted_preasure = linreg.predict(X_poly)

# Visualize the results
plt.scatter(temperature, preasure, color='red')
plt.plot(temperature, predicted_preasure, color='blue')  # Use a line plot for better visualization
plt.title(f'Temperature vs Preasure (Degree = {degree})')
plt.xlabel('Temperature')
plt.ylabel('Preasure')
plt.legend(['Predicted', 'Real Data'])
plt.grid()
plt.show()

# %%
# Create a synthetic dataset
data = {
    'horsepower': [50, 75, 100, 125, 150, 175, 200],
    'mpg': [35, 30, 25, 20, 18, 15, 12]
}
auto_mpg = pd.DataFrame(data)

# Display the dataset
print(auto_mpg)
# Out:
#    horsepower  mpg
# 0          50   35
# 1          75   30
# 2         100   25
# 3         125   20
# 4         150   18
# 5         175   15
# 6         200   12

# %%
# Select features and target
X = auto_mpg[['horsepower']].values  # Input feature
y = auto_mpg['mpg'].values           # Target variable

# Change the degree of the polynomial
degree = 3  # Try different values
polyreg = PolynomialFeatures(degree=degree)

# Transform the input data into polynomial features
X_poly = polyreg.fit_transform(X)

# Fit the model with the transformed data
linreg = LinearRegression()
linreg.fit(X_poly, y)

# Predict the output with the transformed input data
predicted_mpg = linreg.predict(X_poly)

# Visualize the results
plt.scatter(X, y, color='red')
plt.plot(X, predicted_mpg, color='blue')  # Use a line plot for better visualization
plt.title(f'Horsepower vs MPG (Degree = {degree})')
plt.xlabel('Horsepower')
plt.ylabel('MPG')
plt.legend(['Predicted', 'Real Data'])
plt.grid()
plt.show()

# %%
# Create a synthetic dataset
df = pd.DataFrame({
    'your_feature_column': [1, 2, 3, 4, 5],
    'your_target_column': [2, 4, 6, 8, 10]
})

# Select features and target
X = df[['your_feature_column']].values  # Replace with your feature column name
y = df['your_target_column'].values     # Replace with your target column name

# Apply polynomial regression as shown above
degree = 2
polyreg = PolynomialFeatures(degree=degree)
X_poly = polyreg.fit_transform(X)

linreg = LinearRegression()
linreg.fit(X_poly, y)

# Predict and visualize
predicted_y = linreg.predict(X_poly)
plt.scatter(X, y, color='red')
plt.plot(X, predicted_y, color='blue')
plt.title(f'Feature vs Target (Degree = {degree})')
plt.xlabel('Feature')
plt.ylabel('Target')
plt.legend(['Predicted', 'Real Data'])
plt.grid()
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# Create a synthetic dataset
X = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)  # Feature
y = np.array([2, 4, 6, 8, 10])               # Target

# Apply polynomial regression
degree = 2
polyreg = PolynomialFeatures(degree=degree)
X_poly = polyreg.fit_transform(X)

linreg = LinearRegression()
linreg.fit(X_poly, y)

# Predict and visualize
predicted_y = linreg.predict(X_poly)
plt.scatter(X, y, color='red')
plt.plot(X, predicted_y, color='blue')
plt.title(f'Feature vs Target (Degree = {degree})')
plt.xlabel('Feature')
plt.ylabel('Target')
plt.legend(['Predicted', 'Real Data'])
plt.grid()
plt.show()
